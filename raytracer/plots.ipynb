# %%
import pandas as pd
import pandasql as ps
import plotly.graph_objects as go
import numpy as np

# %%
df = pd.read_csv("results.csv")
df
# Out:
#      rep   algo     x     y section       dur
# 0      0    cpu   NaN   NaN   total  0.260232
# 1      0  stock   8.0   4.0   total  0.001427
# 2      0  stock   8.0   4.0  kernel  0.000257
# 3      0     v1   8.0   4.0   total  0.001284
# 4      0     v1   8.0   4.0  kernel  0.000435
# ..   ...    ...   ...   ...     ...       ...
# 459   15     v1  16.0  32.0  kernel  0.000426
# 460   15  stock  32.0  32.0   total  0.001367
# 461   15  stock  32.0  32.0  kernel  0.000262
# 462   15     v1  32.0  32.0   total  0.001211
# 463   15     v1  32.0  32.0  kernel  0.000425
#
# [464 rows x 6 columns]

# %%
total_df = ps.sqldf("""
select algo, x, y, avg(dur) mean, sqrt(avg(dur*dur)-avg(dur)*avg(dur)) std
from df
where section is null or section == 'total'
group by algo, x, y;
""")
total_df
# Out:
#      algo     x     y      mean       std
# 0     cpu   NaN   NaN  0.240617  0.005152
# 1   stock   8.0   4.0  0.002656  0.002751
# 2   stock   8.0   8.0  0.003567  0.004277
# 3   stock   8.0  16.0  0.004786  0.004923
# 4   stock  16.0  16.0  0.003230  0.003051
# 5   stock  16.0  32.0  0.003208  0.002195
# 6   stock  24.0  24.0  0.002170  0.001257
# 7   stock  32.0  32.0  0.003284  0.002723
# 8      v1   8.0   4.0  0.001933  0.001138
# 9      v1   8.0   8.0  0.003151  0.002908
# 10     v1   8.0  16.0  0.002359  0.002074
# 11     v1  16.0  16.0  0.003950  0.003829
# 12     v1  16.0  32.0  0.003277  0.003448
# 13     v1  24.0  24.0  0.003927  0.003895
# 14     v1  32.0  32.0  0.002935  0.002883

# %%
hypers_df = ps.sqldf("""
select algo, mean, std
from total_df
group by algo
having mean = min(mean)
order by algo;
""")
hypers_df
# Out:
#     algo      mean       std
# 0    cpu  0.240617  0.005152
# 1  stock  0.002170  0.001257
# 2     v1  0.001933  0.001138
